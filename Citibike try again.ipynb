# %%
import pandas as pd
from matplotlib import pyplot as plt
data = pd.read_csv('membership-data-2013.csv')

# %%
data
# Out:
#           Date  Trips over the past 24-hours (midnight to 11:59pm)  \
# 0    5/27/2013                                               9767
# 1    5/28/2013                                               5215
# 2    5/29/2013                                              10981
# 3    5/30/2013                                               9850
# 4    5/31/2013                                               9253
# ..         ...                                                ...
# 122  9/26/2013                                              42247
# 123  9/27/2013                                              41368
# 124  9/28/2013                                              38939
# 125  9/29/2013                                              36040
# 126  9/30/2013                                              41079
#
#      Cumulative trips (since launch):  \
# 0                                9767
# 1                               14982
# 2                               25963
# ...

# %%
data['Total Annual Members']
# Out:
# 0      17216
# 1      19816
# 2      21986
# 3      23985
# 4      25615
#        ...
# 122    84305
# 123    84519
# 124    84712
# 125    84913
# 126    85236
# Name: Total Annual Members, Length: 127, dtype: int64

# %%
data['Cumulative trips (since launch):']
# Out:
# 0         9767
# 1        14982
# 2        25963
# 3        35813
# 4        45066
#         ...
# 122    3811754
# 123    3853122
# 124    3892061
# 125    3928101
# 126    3969180
# Name: Cumulative trips (since launch):, Length: 127, dtype: int64

# %%
plt.plot(data['Total Annual Members'], data['Cumulative trips (since launch):'])
plt.xlabel('Total Annual Members')
plt.ylabel('Cumulative trips (since launch):')
plt.show()
